# %% [markdown]
# ### Import Packages

# %%
import requests
import pandas as pd
import geopandas as gpd
from bs4 import BeautifulSoup # pip install beautifulsoup4
from lxml import etree

# %%
url = "https://bharatmaps.gov.in/NewVersion/map.aspx"
response = requests.get(url,verify=False)

# Convert to a beautiful soup object
soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# /home/lohitd@nextbillion.ai/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bharatmaps.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
soup.body
# Out:
# <body class="calcite calcite-maps calcite-nav-top calcite-margin-all calcite-zoom-top-left calcite-layout-inline-left">
# <!-- Navbar -->
# <nav class="navbar calcite-navbar navbar-fixed-top calcite-text-light calcite-bg-dark calcite-bgcolor-dark-purple navbar-fixings col-lg-4 col-sm-12 col-md-6 col-xs-12 x" style="padding:0px 15px 0px 0px;">
# <!-- Menu -->
# <div class="dropdown calcite-dropdown calcite-bg-light calcite-text-dark" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" tabindex="0">
# <div class="calcite-dropdown-toggle">
# <span class="sr-only">Toggle dropdown menu</span>
# <span></span>
# <span></span>
# <span></span>
# <span></span>
# </div>
# </a>
# <ul class="dropdown-menu">
# <li class="bmLogo hidden-md-up" style="margin:1rem 2rem 2rem 2rem;background-color:black;padding:0.4rem 0.8rem;border-bottom:1px solid #dedede;"><img src="img/logo1.png"/></li>
# ...

# %%
for each in soup.find_all('select',{"class":"selectState calcite-form-control"}):
    print(soup.next_sibling)
# Out:
# None

# %%
dom = etree.HTML(str(soup))
print(dom.xpath('//*[@id="35"]'))
# Out:
# []

# %%
for option in select.find_all('option'):
    print(option["value"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-345790846cb4> in <module>
# ----> 1 for option in select.find_all('option'):
#       2     print(option["value"])
#
# NameError: name 'select' is not defined

# %%
# Find select tag
select_tag = soup.find("select")

# find all option tag inside select tag
options = select_tag.find_all("option")

# Iterate through all option tags and get inside text
for option in options:
    print(option)

# %% [markdown]
# ### Getting Response From Query link and Display

# %%
response = requests.get('https://webgis1.nic.in/publishing/rest/services/bharatmaps/admin2019/MapServer/8/query?f=json&where=sdtcode11%3D%20%2705918%27%20and%20dtcode11%20%3D%20%27638%27%20and%20stcode11%20%3D%20%2735%27&returnGeometry=true&spatialRel=esriSpatialRelIntersects&outFields=*')
geojson = response.text
geojson
# Out:
# '{"displayFieldName":"stname","fieldAliases":{"OBJECTID":"OBJECTID","stcode11":"STCODE11","dtcode11":"DTCODE11","sdtcode11":"SDTCODE11","Shape_Length":"Shape_Length","Shape_Area":"Shape_Area","stname":"stname","dtname":"dtname","sdtname":"sdtname","Subdt_LGD":"Subdt_LGD","Dist_LGD":"Dist_LGD","State_LGD":"State_LGD"},"geometryType":"esriGeometryPolygon","spatialReference":{"wkid":102100,"latestWkid":3857},"fields":[{"name":"OBJECTID","type":"esriFieldTypeOID","alias":"OBJECTID"},{"name":"stcode11","type":"esriFieldTypeString","alias":"STCODE11","length":2},{"name":"dtcode11","type":"esriFieldTypeString","alias":"DTCODE11","length":3},{"name":"sdtcode11","type":"esriFieldTypeString","alias":"SDTCODE11","length":5},{"name":"Shape_Length","type":"esriFieldTypeDouble","alias":"Shape_Length"},{"name":"Shape_Area","type":"esriFieldTypeDouble","alias":"Shape_Area"},{"name":"stname","type":"esriFieldTypeString","alias":"stname","length":30},{"name":"dtname","type":"esriFieldTypeString","alia
# ...

# %%
gdft = gpd.read_file(geojson)

# %%
len(gdft)
# Out:
# 1

# %% [markdown]
# ### Reading Geojson in Python Geopandas And Plotting

# %%
gdf = gpd.read_file(geojson)
gdf
gdf.plot()

# %% [markdown]
# ### Reading Links CSV and Display

# %%
df = pd.read_csv('links.csv')
df

# %% [markdown]
# ### Loop on links in csv plot all geojson

# %%
links = df['Link']

# %%
request = f'https://gis.dukcapil.kemendagri.go.id/arcgis/rest/services/Data_Baru_26092017/MapServer/2/query?f=json&where=&returnGeometry=true&spatialRel=esriSpatialRelIntersects&objectIds={7224}&outFields=*&outSR=102100'
response = requests.get(request)
response.text

# %%
state_codes = ['37','12','18','10','22','7','30','24','6','2','1','20','29','32','31','23','27','14','17','15','13','21','34','3','8','11','33','36','16','9','5','19']

# %%
filename = 0 

for each in state_codes:
    try:
        response = requests.get(f'https://webgis1.nic.in/publishing/rest/services/bharatmaps/admin2019/MapServer/6/query?f=json&where=STCODE11%20%3D%20%27{each}%27&returnGeometry=true&spatialRel=esriSpatialRelIntersects&outFields=*')
        geojson = response.text
        gdft = gpd.read_file(geojson)
        path = f'/home/lohitd@nextbillion.ai/Downloads/bharatmaps/{filename}.geojson'
        gdft.to_file(path, driver='GeoJSON')
        filename+=1
        
    except:
        print(each)
# Out:
# 7
# 6
# 2
# 1
# 3
# 8
# 9
# 5

# %%
district_ids = ['640','549','552','542','545','548','553','550','551','546','543','554','547','544','250','257','251','246','253','249','254','248','260','256','252','259','255','258','247','245','319','311','317','313','303','320','307','301','306','314','310','309','308','305','302','300','322','315','318','312','325','316','304','323','324','321','326','225','209','204','231','240','235','203','210','206','222','230','211','227','217','228','215','233','224','229','234','208','236','232','219','221','207','223','220','237','226','238','239','216','212','213','218','214','205','55','412','410','405','409','408','401','413','416','411','402','400','403','414','417','406','407','404','415','496','495','494','585','586','474','488','480','482','468','483','479','492','472','469','477','481','476','490','470','478','486','475','473','485','491','484','471','487','489','493','70','74','84','83','80','85','81','78','73','79','88','86','87','76','89','77','82','72','69','75','71','31','24','26','28','30','23','33','29','27','32','14','21','12','17','22','16','19','15','11','20','18','8','1','7','3','2','6','5','13','10','9','357','347','349','352','362','358','364','368','355','354','361','350','348','346','351','366','360','363','365','369','359','356','353','367','579','555','557','562','574','556','572','563','558','582','559','581','564','577','575','565','568','580','584','570','566','578','567','571','583','561','560','569','573','576','599','598','595','589','601','594','597','593','591','590','588','600','596','592','436','426','420','465','434','461','429','455','419','447','441','421','458','459','445','432','449','425','424','423','446','435','438','418','422','437','457','430','454','427','451','456','450','440','443','460','444','439','433','442','467','431','466','452','462','428','453','448','464','463','504','503','508','522','524','526','501','521','520','499','514','517','523','511','507','500','531','512','515','509','510','516','506','505','525','528','527','529','497','498','530','513','519','502','278','275','276','277','280','295','299','296','297','294','298','293','283','282','284','286','287','281','285','288','261','264','262','266','265','271','269','270','267','268','263','97','93','94','91','98','375','384','388','381','370','393','377','390','399','386','376','378','391','371','395','383','392','374','372','382','385','373','396','380','398','389','379','394','387','397','637','635','636','634','43','37','53','49','40','51','42','39','50','52','47','44','54','35','46','36','48','38','41','45','117','119','129','104','123','128','99','122','103','110','118','115','109','125','106','126','105','100','130','116','102','101','113','121','131','112','120','124','111','108','107','127','114','244','242','243','241','623','626','628','604','611','620','612','629','609','605','621','632','627','610','607','624','617','606','602','608','613','616','615','625','633','630','614','631','603','622','618','619','538','532','535','533','537','539','540','536','534','541','289','290','291','292','162','146','192','134','139','135','199','133','174','163','178','201','143','175','152','149','202','132','179','157','137','187','173','142','150','170','191','156','177','140','158','194','195','180','138','172','145','161','193','182','185','176','188','184','166','190','151','153','155','148','198','181','141','136','164','154','196','169','160','171','200','183','147','159','197','168','186','144','189','165','167','64','58','57','63','67','65','56','62','68','66','59','60','61','328','338','335','337','331','339','343','333','336','334','344','345','330','327','329','332','341','340','342']

# %%
filename = 0 

for each in district_ids:
    try:
        response = requests.get(f'https://webgis1.nic.in/publishing/rest/services/bharatmaps/admin2019/MapServer/7/query?f=json&where=dtcode11%20%3D%20%27{each}%27&returnGeometry=true&spatialRel=esriSpatialRelIntersects&outFields=*')
        geojson = response.text
        gdft = gpd.read_file(geojson)
        path = f'/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/{filename}.geojson'
        gdft.to_file(path, driver='GeoJSON')
        filename+=1
        
    except:
        print(each)
# Out:
# 55
# 70
# 74
# 84
# 83
# 80
# 85
# 81
# 78
# 73
# 79
# 88
# 86
# 87
# 76
# 89
# 77
# 82
# 72
# 69
# 75
# 71
# 31
# 24
# 26
# 28
# 30
# 23
# 33
# 29
# 27
# 32
# 14
# 21
# 12
# 17
# 22
# 16
# 19
# 15
# 11
# 20
# 18
# 8
# 1
# 7
# 3
# 2
# 6
# 5
# 13
# 10
# 9
# 97
# 93
# 94
# 91
# 98
# 43
# 37
# 53
# 49
# 40
# 51
# 42
# 39
# 50
# 52
# 47
# 44
# 54
# 35
# 46
# 36
# 48
# 38
# 41
# 45
# 99
# 64
# 58
# 57
# 63
# 67
# 65
# 56
# 62
# 68
# 66
# 59
# 60
# 61

# %%
len(state_codes)a
# Out:
# 32

# %%
gdf0 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/0.geojson")
gdf1 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/1.geojson")
gdf2 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/2.geojson")
gdf3 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/3.geojson")
gdf4 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/4.geojson")
gdf5 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/5.geojson")
gdf6 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/6.geojson")
gdf7 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/7.geojson")
gdf8 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/8.geojson")
gdf9 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/9.geojson")
gdf10 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/10.geojson")
gdf11 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/11.geojson")
gdf12 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/12.geojson")
gdf13 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/13.geojson")
gdf14 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/14.geojson")
gdf15 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts
f321,gdf322,gdf323,gdf324,gdf325,gdf326,gdf327,gdf328,gdf329,gdf330,gdf331,gdf332,gdf333,gdf334,gdf335,gdf336,gdf337,gdf338,gdf339,gdf340,gdf341,gdf342,gdf343,gdf344,gdf345,gdf346,gdf347,gdf348,gdf349,gdf350,gdf351,gdf352,gdf353,gdf354,gdf355,gdf356,gdf357,gdf358,gdf359,gdf360,gdf361,gdf362,gdf363,gdf364,gdf365,gdf366,gdf367,gdf368,gdf369,gdf370,gdf371,gdf372,gdf373,gdf374,gdf375,gdf376,gdf377,gdf378,gdf379,gdf380,gdf381,gdf382,gdf383,gdf384,gdf385,gdf386,gdf387,gdf388,gdf389,gdf390,gdf391,gdf392,gdf393,gdf394,gdf395,gdf396,gdf397,gdf398,gdf399,gdf400,gdf401,gdf402,gdf403,gdf404,gdf405,gdf406,gdf407,gdf408,gdf409,gdf410,gdf411,gdf412,gdf413,gdf414,gdf415,gdf416,gdf417,gdf418,gdf419,gdf420,gdf421,gdf422,gdf423,gdf424,gdf425,gdf426,gdf427,gdf428,gdf429,gdf430,gdf431,gdf432,gdf433,gdf434,gdf435,gdf436,gdf437,gdf438,gdf439,gdf440,gdf441,gdf442,gdf443,gdf444,gdf445,gdf446,gdf447,gdf448,gdf449,gdf450,gdf451,gdf452,gdf453,gdf454,gdf455,gdf456,gdf457,gdf458,gdf459,gdf460,gdf461,gdf462,gdf463,gdf464,gdf465,gdf466,gdf467,gdf468,gdf469,gdf470,gdf471,gdf472,gdf473,gdf474,gdf475,gdf476,gdf477,gdf478,gdf479,gdf480,gdf481,gdf482,gdf483,gdf484,gdf485,gdf486,gdf487,gdf488,gdf489,gdf490,gdf491,gdf492,gdf493,gdf494,gdf495,gdf496,gdf497,gdf498,gdf499,gdf500,gdf501,gdf502,gdf503,gdf504,gdf505,gdf506,gdf507,gdf508,gdf509,gdf510,gdf511,gdf512,gdf513,gdf514,gdf515,gdf516,gdf517,gdf518,gdf519,gdf520,gdf521,gdf522,gdf523,gdf524,gdf525,gdf526,gdf527,gdf528,gdf529,gdf530,gdf531,gdf532], ignore_index=True) )

# %%
districts.to_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/districts.geojson", driver='GeoJSON')

# %%
complete_states_districts = gpd.GeoDataFrame( pd.concat( [districts,states], ignore_index=True) )

# %%
complete_states_districts.to_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/districts/complete_states_districts.geojson", driver='GeoJSON')

# %%
len(complete_states_districts)
# Out:
# 556

# %%
len(districts)
# Out:
# 533

# %%
len(states)
# Out:
# 23

# %%
gdf0 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/0.geojson")
gdf1 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/1.geojson")
gdf2 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/2.geojson")
gdf3 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/3.geojson")
gdf4 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/4.geojson")
gdf5 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/5.geojson")
gdf6 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/6.geojson")
gdf7 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/7.geojson")
gdf8 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/8.geojson")
gdf9 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/9.geojson")
gdf10 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/10.geojson")
gdf11 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/11.geojson")
gdf12 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/12.geojson")
gdf13 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/13.geojson")
gdf14 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/14.geojson")
gdf15 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/15.geojson")
gdf16 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/16.geojson")
gdf17 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/17.geojson")
gdf18 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/18.geojson")
gdf19 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/19.geojson")
gdf20 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/20.geojson")
gdf21 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/21.geojson")
gdf22 = gpd.read_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/22.geojson")

# %%
states = gpd.GeoDataFrame( pd.concat( [gdf0,gdf1,gdf2,gdf3,gdf4,gdf5,gdf6,gdf7,gdf8,gdf9,gdf10,gdf11,gdf12,gdf13,gdf14,gdf15,gdf16,gdf17,gdf18,gdf19,gdf20,gdf21,gdf22], ignore_index=True) )

# %%
states.to_file("/home/lohitd@nextbillion.ai/Downloads/bharatmaps/states.geojson" ,driver="GeoJSON")

# %%
gdft
# Out:
# Empty GeoDataFrame
# Columns: [OBJECTID, stcode11, dtcode11, sdtcode11, Shape_Length, Shape_Area, stname, dtname, sdtname, Subdt_LGD, Dist_LGD, State_LGD, geometry]
# Index: []

# %%
each

# %%
filename = 2

for each in range(7279):
    gdf_read = gpd.read_file(f'/home/lohitd@nextbillion.ai/Downloads/ID/{filename}.geojson')
    complete = pd.concat([complete,gdf_read], axis=0)
    filename+=1

# %%
complete.to_file('/home/lohitd@nextbillion.ai/Downloads/ID/id.geojson', driver ='GeoJSON')

# %%
complete1 = complete[["giskemendagri.gisadmin.Kecamatan_Tabel_26092017.nama_prop_","giskemendagri.gisadmin.Kecamatan_Tabel_26092017.nama_kab_s","giskemendagri.gisadmin.Kecamatan_Spasial_22092017_2.nama_siak","giskemendagri.gisadmin.Kecamatan_Tabel_26092017.kode_kec_s","geometry"]]

# %%
complete1 = complete1.rename(columns={"giskemendagri.gisadmin.Kecamatan_Tabel_26092017.nama_prop_":"level_1","giskemendagri.gisadmin.Kecamatan_Tabel_26092017.nama_kab_s":"level_2","giskemendagri.gisadmin.Kecamatan_Spasial_22092017_2.nama_siak":"division_name","giskemendagri.gisadmin.Kecamatan_Tabel_26092017.kode_kec_s":"division_id"})

# %%
complete1['region'] = "ID"
complete1['division_level'] = "3"
complete1['level_0'] = "Indonesia"

# %%
complete1['province_city'] = complete1['level_1'] + ", " + complete1['level_2']

# %%
complete1.to_file('/home/lohitd@nextbillion.ai/Downloads/ID/ID_shpfile/id1.shp')

# %%
complete = gpd.read_file(f'/home/lohitd@nextbillion.ai/Downloads/ID/1.geojson')

# %%
complete1 = complete[['giskemendagri.gisadmin.Kecamatan_Spasial_22092017_2.objectid_1','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.objectid','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.no_prop','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.no_kab','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.no_kec','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.kode_prov_','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.kode_kab_s','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.kode_kec_s','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.nama_prop_','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.nama_kab_s','giskemendagri.gisadmin.Kecamatan_Tabel_26092017.nama_kec_s','giskemendagri.gisadmin.Kecamatan_Spasial_22092017_2.kode_siak','giskemendagri.gisadmin.Kecamatan_Spasial_22092017_2.nama_siak','giskemendagri.gisadmin.Kecamatan_Spasial_22092017_2.kode_2017','giskemendagri.gisadmin.Kecamatan_Spasial_22092017_2.nama_2017']]

# %%
Starting_number = 7224
Ending_number = 14502
total_polygons = 7280
